# %%
cd
# Out:
# C:\Users\LENOVO

# %%
# %config IPCompleter.greedy=True

# %%
#Importing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
# Main function
def main():
    #Step 1 = ask user to read the csv
    return read()
    
main()
# Out:
# path to your csv please:  gta_cities_minorities_geocoded.csv
#          GEO   latitude  longitude  REF_DATE_x           DGUID_x    Age (15C)  \
# 0  Pickering  43.835765 -79.090576  2021-01-01  2021A00053518001  Total - Age
# 1  Pickering  43.835765 -79.090576  2021-01-01  2021A00053518001  Total - Age
# 2  Pickering  43.835765 -79.090576  2021-01-01  2021A00053518001  Total - Age
# 3  Pickering  43.835765 -79.090576  2021-01-01  2021A00053518001  Total - Age
# 4  Pickering  43.835765 -79.090576  2021-01-01  2021A00053518001  Total - Age
#
#        Gender (3)         Statistics (2) Coordinate_x  \
# 0  Total - Gender            2021 Counts    489.1.1.1
# 1  Total - Gender  % distribution (2021)    489.1.1.2
# 2            Men+            2021 Counts    489.1.2.1
# 3            Men+  % distribution (2021)    489.1.2.2
# 4          Women+            2021 Counts    489.1.3.1
#
#    Visible minority (15):Total - Visible minority[1]  ...  \
# ...

# %%
# Function to read
def read():
    csv = input("path to your csv please: ") 
    data_from_csv = pd.read_csv(csv)
    return data_from_csv.head()
read()
# Out:
# path to your csv please:  gta_cities_minorities_geocoded.csv
#          GEO   latitude  longitude  REF_DATE_x           DGUID_x    Age (15C)  \
# 0  Pickering  43.835765 -79.090576  2021-01-01  2021A00053518001  Total - Age
# 1  Pickering  43.835765 -79.090576  2021-01-01  2021A00053518001  Total - Age
# 2  Pickering  43.835765 -79.090576  2021-01-01  2021A00053518001  Total - Age
# 3  Pickering  43.835765 -79.090576  2021-01-01  2021A00053518001  Total - Age
# 4  Pickering  43.835765 -79.090576  2021-01-01  2021A00053518001  Total - Age
#
#        Gender (3)         Statistics (2) Coordinate_x  \
# 0  Total - Gender            2021 Counts    489.1.1.1
# 1  Total - Gender  % distribution (2021)    489.1.1.2
# 2            Men+            2021 Counts    489.1.2.1
# 3            Men+  % distribution (2021)    489.1.2.2
# 4          Women+            2021 Counts    489.1.3.1
#
#    Visible minority (15):Total - Visible minority[1]  ...  \
# ...

# %%
# Clean the data
def clean():
    data = read()
    #Remove the null values
    data = data.dropna(axis=1,how="any") 
    #Remove the duplicates
    #data = data.drop_duplicates(inplace='True')
    #Detect and Remove outliers
    z_scores = stats.zscore(data.select_dtypes(include=['int16', 'int32', 'int64', 'float16', 'float32', 'float64']))
    # Calculate the 1st and 99th percentile thresholds
    lower_threshold = stats.norm.ppf(0.01)
    upper_threshold = stats.norm.ppf(0.99)

    # Filter data based on z-score thresholds
    filtered_entries = (z_scores > lower_threshold) & (z_scores < upper_threshold)
    filtered_data = data[filtered_entries.all(axis=1)]
